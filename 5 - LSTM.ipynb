# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('talk')
import warnings
warnings.filterwarnings('ignore')

import os
cwd = os.getcwd().split('\\')
local_repo_path = '\\'.join(cwd[:-1])
raw_data_path = local_repo_path + '\\data\\raw'
processed_data_path = local_repo_path + '\\data\\processed'
feature_path = local_repo_path + '\\data\\features'
model_path = local_repo_path + '\\model_submissions'

# %%
output_feature_fname = 'Lookback10'
sj_feature_train = pd.read_csv(feature_path + r'\\sj_train_' + output_feature_fname + '.csv', index_col = 0)
sj_feature_test = pd.read_csv(feature_path + r'\\sj_test_' + output_feature_fname + '.csv', index_col = 0)
iq_feature_train = pd.read_csv(feature_path + r'\\iq_train_' + output_feature_fname + '.csv', index_col = 0)
iq_feature_test = pd.read_csv(feature_path + r'\\iq_test_' + output_feature_fname + '.csv', index_col = 0)

# %%
sj_feature_test.head()
# Out:
#    var1(t-10)  var2(t-10)  var3(t-10)  var4(t-10)  var5(t-10)  var1(t-9)  \
# 0   -0.880088   -0.902578   -0.992343   -0.500000   -0.261864  -1.099356
# 1   -1.099356   -1.148990   -1.059724   -0.772727   -0.300411  -0.904755
# 2   -0.904755   -0.934355   -0.900459   -0.772727   -0.338042  -1.193641
# 3   -1.193641   -1.268293   -0.808576   -0.272727   -0.374707  -1.187611
# 4   -1.187611   -1.264948   -0.863706   -1.000000   -0.409986  -1.223242
#
#    var2(t-9)  var3(t-9)  var4(t-9)  var5(t-9)  ...  var4(t-2)  var5(t-2)  \
# 0  -1.148990  -1.059724  -0.772727  -0.300411  ...  -0.500000  -0.520492
# 1  -0.934355  -0.900459  -0.772727  -0.338042  ...   0.227273  -0.535167
# 2  -1.268293  -0.808576  -0.272727  -0.374707  ...  -0.500000  -0.542448
# 3  -1.264948  -0.863706  -1.000000  -0.409986  ...  -0.272727  -0.541333
# 4  -1.307875  -0.931087  -0.772727  -0.443178  ...   0.000000  -0.530953
#
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  city  year  \
# 0  -0.445389  -0.455470  -0.073507   0.227273  -0.535167    sj  2008
# 1  -0.350555  -0.359024  -0.294028  -0.500000  -0.542448    sj  2008
# 2  -0.399342  -0.410314  -0.490046  -0.272727  -0.541333    sj  2008
# 3  -0.060573  -0.054077   0.306279   0.000000  -0.530953    sj  2008
# 4  -0.405372  -0.407526   0.361409   0.727273  -0.510605    sj  2008
#
#    weekofyear
# 0          18
# 1          19
# 2          20
# 3          21
# 4          22
#
# [5 rows x 53 columns]

# %%
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from math import sqrt
from matplotlib import pyplot
from numpy import array
from sklearn.metrics import mean_absolute_error
# Out:
# Using TensorFlow backend.

# %%
def fit_and_predict_LSTM(train_wide, test_wide, epochs = 200, n_hidden = 25, activation = 'linear', verbose = 0):
    values = train_wide.values
    n_train = values.shape[0] - 200
    train = values[:n_train, :]
    val = values[n_train:, :]
    
    train_x, train_y = train[:, :-1], train[:, -1]
    val_x, val_y = val[:, :-1], val[:, -1]
    
    train_x = train_x.reshape((train_x.shape[0], 1, train_x.shape[1]))
    val_x = val_x.reshape((val_x.shape[0], 1, val_x.shape[1]))
    test_x = test_wide.drop(['city', 'year', 'weekofyear'], axis = 1).values
    test_x = test_x.reshape((test_x.shape[0], 1, test_x.shape[1]))
    
    model = Sequential()
    model.add(LSTM(n_hidden, input_shape=(train_x.shape[1], train_x.shape[2])))
    model.add(Dropout(0.4))
    model.add(Dense(n_hidden))
    model.add(Dropout(0.4))
    model.add(Dense(1))
    model.compile(loss='mae', optimizer='adam')
    
    history = model.fit(train_x, train_y, epochs = epochs, batch_size = 72, validation_data = (val_x, val_y), verbose = verbose, shuffle = False)
    
    plt.figure(figsize = (7,5))
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='val')
    plt.legend()
    plt.show()
    
    test_preds = model.predict(test_x)
    
    train_x_full = values[:, :-1]
    train_preds = model.predict(train_x_full.reshape((train_x_full.shape[0], 1, train_x_full.shape[1])))
    fig, ax = plt.subplots(figsize = (20,10))
    train_error = np.round(mean_absolute_error(train_preds, train_wide['total_cases']), 1)
    pd.DataFrame(train_preds).plot(ax = ax)
    pd.DataFrame(train_wide['total_cases']).reset_index(drop = True).plot(ax = ax)
    pd.DataFrame(test_preds).set_index(np.arange(len(train_wide), len(train_wide) + len(test_preds))).plot(ax = ax)
    
    ax.legend(labels = ['Fitted', 'True', 'Predicted'])
    ax.set_title('Mean train error: ' + str(train_error))
    return(model, train_preds, test_preds)

# %%
sj_feature_train_log_cases = sj_feature_train.copy()
sj_feature_train_log_cases['total_cases'] = np.log(1 + sj_feature_train_log_cases['total_cases'])

# %%
sj_model, sj_train_preds, sj_test_preds = fit_and_predict_LSTM(sj_feature_train, sj_feature_test, epochs = 400, n_hidden = 40, verbose = 2)
# Out:
# WARNING:tensorflow:From C:\Users\kartikey-pc\anaconda3\envs\env2\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 726 samples, validate on 200 samples
# Epoch 1/400
#  - 1s - loss: 37.2849 - val_loss: 23.6729
# Epoch 2/400
#  - 0s - loss: 36.9313 - val_loss: 23.2973
# Epoch 3/400
#  - 0s - loss: 36.4231 - val_loss: 22.7720
# Epoch 4/400
#  - 0s - loss: 35.7260 - val_loss: 22.1886
# Epoch 5/400
#  - 0s - loss: 34.7978 - val_loss: 21.4848
# Epoch 6/400
#  - 0s - loss: 33.7731 - val_loss: 20.6204
# Epoch 7/400
#  - 0s - loss: 32.5759 - val_loss: 19.7494
# Epoch 8/400
#  - 0s - loss: 31.3475 - val_loss: 18.7395
# Epoch 9/400
#  - 0s - loss: 30.2118 - val_loss: 17.8344
# Epoch 10/400
#  - 0s - loss: 28.8939 - val_loss: 17.2727
# Epoch 11/400
#  - 0s - loss: 27.5066 - val_loss: 17.1094
# Epoch 12/400
#  - 0s - loss: 26.3203 - val_loss: 17.0794
# Epoch 13/400
#  - 0s - loss: 25.3992 - val_loss: 17.3197
# Epoch 14/400
#  - 0s - loss: 24.8644 - val_loss: 17.6327
# Epoch 15/400
#  - 0s - loss: 24.2206 - val_loss: 17.8812
# Epoch 16/400
#  - 0s - loss: 24.2944 - val_loss: 17.9061
# Epoch 17/400
#  - 0s - loss: 23.9209 - val_loss: 17.8566
# Epoch 18/400
#  - 0s - loss: 23.5790 - val_loss: 17.9044
# Epoch 19/400
#  - 0s - loss: 23.6567 - val_loss: 17.9843
# Epoch 20/400
#  - 0s - loss: 23.9628 - val_loss: 18.1748
# Epoch 21/400
#  - 0s - loss: 23.6652 - val_loss: 18.3948
# Epoch 22/400
#  - 0s - loss: 23.6509 - val_loss: 18.3794
# Epoch 23/400
#  - 0s - loss: 23.5465 - val_loss: 18.3696
# Epoch 24/400
#  - 0s - loss: 23.4651 - val_loss: 18.4065
# Epoch 25/400
#  - 0s - loss: 23.6816 - val_loss: 18.4554
# Epoch 26/400
#  - 0s - loss: 23.5941 - val_loss: 18.4896
# Epoch 27/400
#  - 0s - loss: 23.7132 - val_loss: 18.2794
# Epoch 28/400
#  - 0s - loss: 23.4397 - val_loss: 18.0977
# Epoch 29/400
#  - 0s - loss: 23.7691 - val_loss: 18.0894
# Epoch 30/400
#  - 0s - loss: 23.4948 - val_loss: 18.2514
# Epoch 31/400
#  - 0s - loss: 23.5580 - val_loss: 18.2901
# Epoch 32/400
#  - 0s - loss: 23.1352 - val_loss: 18.4062
# Epoch 33/400
#  - 0s - loss: 23.4264 - val_loss: 18.4736
# Epoch 34/400
#  - 0s - loss: 23.4720 - val_loss: 18.4397
# Epoch 35/400
#  - 0s - loss: 22.9571 - val_loss: 18.4324
# Epoch 36/400
#  - 0s - loss: 23.4322 - val_loss: 18.4746
# Epoch 37/400
#  - 0s - loss: 23.2865 - val_loss: 18.3689
# Epoch 38/400
#  - 0s - loss: 23.1293 - val_loss: 18.2233
# Epoch 39/400
#  - 0s - loss: 23.0098 - val_loss: 18.2234
# Epoch 40/400
#  - 0s - loss: 23.1602 - val_loss: 18.3231
# Epoch 41/400
#  - 0s - loss: 23.2584 - val_loss: 18.4377
# Epoch 42/400
#  - 0s - loss: 23.3630 - val_loss: 18.7503
# Epoch 43/400
#  - 0s - loss: 23.0423 - val_loss: 18.6812
# Epoch 44/400
#  - 0s - loss: 23.4484 - val_loss: 18.4518
# Epoch 45/400
#  - 0s - loss: 22.9422 - val_loss: 18.2785
# Epoch 46/400
#  - 0s - loss: 23.0541 - val_loss: 18.1108
# Epoch 47/400
#  - 0s - loss: 23.5606 - val_loss: 18.0334
# Epoch 48/400
#  - 0s - loss: 23.1926 - val_loss: 17.9223
# Epoch 49/400
#  - 0s - loss: 23.1505 - val_loss: 17.8663
# Epoch 50/400
#  - 0s - loss: 22.9478 - val_loss: 18.0520
# Epoch 51/400
#  - 0s - loss: 23.3614 - val_loss: 18.1099
# Epoch 52/400
#  - 0s - loss: 22.7240 - val_loss: 18.1112
# Epoch 53/400
#  - 0s - loss: 23.0855 - val_loss: 18.1078
# Epoch 54/400
#  - 0s - loss: 23.2223 - val_loss: 18.1008
# Epoch 55/400
#  - 0s - loss: 23.1016 - val_loss: 17.9688
# Epoch 56/400
#  - 0s - loss: 22.8531 - val_loss: 18.0385
# Epoch 57/400
#  - 0s - loss: 23.2411 - val_loss: 18.1494
# Epoch 58/400
#  - 0s - loss: 22.9252 - val_loss: 18.1316
# Epoch 59/400
#  - 0s - loss: 23.0660 - val_loss: 18.0497
# Epoch 60/400
#  - 0s - loss: 22.9351 - val_loss: 18.0233
# Epoch 61/400
#  - 0s - loss: 22.8312 - val_loss: 17.9584
# Epoch 62/400
#  - 0s - loss: 23.0968 - val_loss: 18.0735
# Epoch 63/400
#  - 0s - loss: 23.2476 - val_loss: 18.2265
# Epoch 64/400
#  - 0s - loss: 22.9028 - val_loss: 18.2054
# Epoch 65/400
#  - 0s - loss: 23.1012 - val_loss: 18.0796
# Epoch 66/400
#  - 0s - loss: 22.6749 - val_loss: 18.0591
# Epoch 67/400
#  - 0s - loss: 23.0244 - val_loss: 18.0472
# Epoch 68/400
#  - 0s - loss: 22.8703 - val_loss: 17.8921
# Epoch 69/400
#  - 0s - loss: 22.6592 - val_loss: 17.9301
# Epoch 70/400
#  - 0s - loss: 22.8560 - val_loss: 18.0673
# Epoch 71/400
#  - 0s - loss: 22.9366 - val_loss: 18.1292
# Epoch 72/400
#  - 0s - loss: 22.7195 - val_loss: 18.2518
# Epoch 73/400
#  - 0s - loss: 22.5041 - val_loss: 18.3501
# Epoch 74/400
#  - 0s - loss: 22.8037 - val_loss: 18.3226
# Epoch 75/400
#  - 0s - loss: 22.5946 - val_loss: 18.3491
# Epoch 76/400
#  - 0s - loss: 22.7931 - val_loss: 18.4178
# Epoch 77/400
#  - 0s - loss: 22.6348 - val_loss: 18.3438
# Epoch 78/400
#  - 0s - loss: 22.8403 - val_loss: 18.2928
# Epoch 79/400
#  - 0s - loss: 22.9483 - val_loss: 18.2566
# Epoch 80/400
#  - 0s - loss: 22.7145 - val_loss: 18.2278
# Epoch 81/400
#  - 0s - loss: 22.5864 - val_loss: 18.3157
# Epoch 82/400
#  - 0s - loss: 22.6244 - val_loss: 18.2791
# Epoch 83/400
#  - 0s - loss: 22.5979 - val_loss: 18.2542
# Epoch 84/400
#  - 0s - loss: 22.8832 - val_loss: 18.2097
# Epoch 85/400
#  - 0s - loss: 22.5725 - val_loss: 18.2357
# Epoch 86/400
#  - 0s - loss: 22.4964 - val_loss: 18.1717
# Epoch 87/400
#  - 0s - loss: 22.7184 - val_loss: 18.0999
# Epoch 88/400
#  - 0s - loss: 22.4876 - val_loss: 18.1733
# Epoch 89/400
#  - 0s - loss: 22.7806 - val_loss: 18.2291
# Epoch 90/400
#  - 0s - loss: 22.6010 - val_loss: 18.4108
# Epoch 91/400
#  - 0s - loss: 22.5847 - val_loss: 18.2958
# Epoch 92/400
#  - 0s - loss: 22.4085 - val_loss: 18.2656
# Epoch 93/400
#  - 0s - loss: 22.7783 - val_loss: 18.2890
# Epoch 94/400
#  - 0s - loss: 22.5723 - val_loss: 18.2861
# Epoch 95/400
#  - 0s - loss: 22.7167 - val_loss: 18.4474
# Epoch 96/400
#  - 0s - loss: 22.8470 - val_loss: 18.5242
# Epoch 97/400
#  - 0s - loss: 22.5610 - val_loss: 18.5110
# Epoch 98/400
#  - 0s - loss: 22.6863 - val_loss: 18.3467
# Epoch 99/400
#  - 0s - loss: 22.6881 - val_loss: 18.2368
# Epoch 100/400
#  - 0s - loss: 22.8272 - val_loss: 18.3394
# Epoch 101/400
#  - 0s - loss: 22.4945 - val_loss: 18.4391
# Epoch 102/400
#  - 0s - loss: 22.3686 - val_loss: 18.6754
# Epoch 103/400
#  - 0s - loss: 22.4451 - val_loss: 18.7448
# Epoch 104/400
#  - 0s - loss: 22.3799 - val_loss: 18.6717
# Epoch 105/400
#  - 0s - loss: 22.5644 - val_loss: 18.5351
# Epoch 106/400
#  - 0s - loss: 22.7617 - val_loss: 18.4854
# Epoch 107/400
#  - 0s - loss: 22.4466 - val_loss: 18.5726
# Epoch 108/400
#  - 0s - loss: 22.5355 - val_loss: 18.6012
# Epoch 109/400
#  - 0s - loss: 22.7443 - val_loss: 18.5331
# Epoch 110/400
#  - 0s - loss: 22.2830 - val_loss: 18.5376
# Epoch 111/400
#  - 0s - loss: 22.2979 - val_loss: 18.6042
# Epoch 112/400
#  - 0s - loss: 22.4261 - val_loss: 18.6189
# Epoch 113/400
#  - 0s - loss: 22.3309 - val_loss: 18.6773
# Epoch 114/400
#  - 0s - loss: 22.5192 - val_loss: 18.7232
# Epoch 115/400
#  - 0s - loss: 22.3703 - val_loss: 18.5574
# Epoch 116/400
#  - 0s - loss: 22.5116 - val_loss: 18.5151
# Epoch 117/400
#  - 0s - loss: 22.6195 - val_loss: 18.5796
# Epoch 118/400
#  - 0s - loss: 22.6348 - val_loss: 18.4480
# Epoch 119/400
#  - 0s - loss: 22.3821 - val_loss: 18.4965
# Epoch 120/400
#  - 0s - loss: 22.0020 - val_loss: 18.7609
# Epoch 121/400
#  - 0s - loss: 22.8495 - val_loss: 18.8270
# Epoch 122/400
#  - 0s - loss: 22.8252 - val_loss: 18.7332
# Epoch 123/400
#  - 0s - loss: 22.6453 - val_loss: 18.5033
# Epoch 124/400
#  - 0s - loss: 22.3855 - val_loss: 18.5061
# Epoch 125/400
#  - 0s - loss: 22.4402 - val_loss: 18.5178
# Epoch 126/400
#  - 0s - loss: 22.5063 - val_loss: 18.4303
# Epoch 127/400
#  - 0s - loss: 22.3594 - val_loss: 18.5084
# Epoch 128/400
#  - 0s - loss: 22.3291 - val_loss: 18.5445
# Epoch 129/400
#  - 0s - loss: 22.5425 - val_loss: 18.4177
# Epoch 130/400
#  - 0s - loss: 22.3734 - val_loss: 18.5069
# Epoch 131/400
#  - 0s - loss: 22.3846 - val_loss: 18.7900
# Epoch 132/400
#  - 0s - loss: 22.3292 - val_loss: 18.7579
# Epoch 133/400
#  - 0s - loss: 22.1041 - val_loss: 18.7745
# Epoch 134/400
#  - 0s - loss: 22.3463 - val_loss: 18.8510
# Epoch 135/400
#  - 0s - loss: 22.3008 - val_loss: 18.7828
# Epoch 136/400
#  - 0s - loss: 22.3208 - val_loss: 18.8224
# Epoch 137/400
#  - 0s - loss: 22.3161 - val_loss: 18.8570
# Epoch 138/400
#  - 0s - loss: 22.6099 - val_loss: 19.0056
# Epoch 139/400
#  - 0s - loss: 22.7484 - val_loss: 18.8629
# Epoch 140/400
#  - 0s - loss: 22.1384 - val_loss: 18.6510
# Epoch 141/400
#  - 0s - loss: 22.4162 - val_loss: 18.6269
# Epoch 142/400
#  - 0s - loss: 22.3807 - val_loss: 18.6357
# Epoch 143/400
#  - 0s - loss: 22.5507 - val_loss: 18.6257
# Epoch 144/400
#  - 0s - loss: 21.9606 - val_loss: 18.7290
# Epoch 145/400
#  - 0s - loss: 22.5773 - val_loss: 18.9784
# Epoch 146/400
#  - 0s - loss: 22.0724 - val_loss: 18.8352
# Epoch 147/400
#  - 0s - loss: 22.2111 - val_loss: 18.6553
# Epoch 148/400
#  - 0s - loss: 22.4849 - val_loss: 18.7446
# Epoch 149/400
#  - 0s - loss: 22.0811 - val_loss: 18.7570
# Epoch 150/400
#  - 0s - loss: 22.1919 - val_loss: 18.8047
# Epoch 151/400
#  - 0s - loss: 21.8250 - val_loss: 18.8546
# Epoch 152/400
#  - 0s - loss: 21.8582 - val_loss: 18.7885
# Epoch 153/400
#  - 0s - loss: 22.0969 - val_loss: 18.7360
# Epoch 154/400
#  - 0s - loss: 22.4329 - val_loss: 18.8590
# Epoch 155/400
#  - 0s - loss: 22.6201 - val_loss: 19.0562
# Epoch 156/400
#  - 0s - loss: 22.1331 - val_loss: 19.0670
# Epoch 157/400
#  - 0s - loss: 22.4108 - val_loss: 19.0370
# Epoch 158/400
#  - 0s - loss: 22.0366 - val_loss: 19.0229
# Epoch 159/400
#  - 0s - loss: 21.9087 - val_loss: 18.9775
# Epoch 160/400
#  - 0s - loss: 22.0620 - val_loss: 18.9034
# Epoch 161/400
#  - 0s - loss: 21.8635 - val_loss: 18.7710
# Epoch 162/400
#  - 0s - loss: 21.7543 - val_loss: 18.8014
# Epoch 163/400
#  - 0s - loss: 22.2056 - val_loss: 18.8435
# Epoch 164/400
#  - 0s - loss: 22.0856 - val_loss: 18.8617
# Epoch 165/400
#  - 0s - loss: 22.1571 - val_loss: 19.0203
# Epoch 166/400
#  - 0s - loss: 21.9870 - val_loss: 19.0963
# Epoch 167/400
#  - 0s - loss: 22.0900 - val_loss: 18.8939
# Epoch 168/400
#  - 0s - loss: 22.6604 - val_loss: 18.6232
# Epoch 169/400
#  - 0s - loss: 22.0708 - val_loss: 18.5356
# Epoch 170/400
#  - 0s - loss: 21.9470 - val_loss: 18.6857
# Epoch 171/400
#  - 0s - loss: 22.0092 - val_loss: 18.8074
# Epoch 172/400
#  - 0s - loss: 21.9941 - val_loss: 18.8503
# Epoch 173/400
#  - 0s - loss: 22.0665 - val_loss: 18.7536
# Epoch 174/400
#  - 0s - loss: 21.8847 - val_loss: 18.8134
# Epoch 175/400
#  - 0s - loss: 21.5642 - val_loss: 18.7599
# Epoch 176/400
#  - 0s - loss: 21.7885 - val_loss: 18.7024
# Epoch 177/400
#  - 0s - loss: 22.0430 - val_loss: 18.6029
# Epoch 178/400
#  - 0s - loss: 22.3589 - val_loss: 18.5105
# Epoch 179/400
#  - 0s - loss: 21.7352 - val_loss: 18.6764
# Epoch 180/400
#  - 0s - loss: 21.9532 - val_loss: 18.8405
# Epoch 181/400
#  - 0s - loss: 21.8872 - val_loss: 18.8131
# Epoch 182/400
#  - 0s - loss: 22.2089 - val_loss: 18.6676
# Epoch 183/400
#  - 0s - loss: 21.9527 - val_loss: 18.7120
# Epoch 184/400
#  - 0s - loss: 21.9044 - val_loss: 18.9374
# Epoch 185/400
#  - 0s - loss: 22.1683 - val_loss: 18.9277
# Epoch 186/400
#  - 0s - loss: 22.1903 - val_loss: 18.6923
# Epoch 187/400
#  - 0s - loss: 21.9463 - val_loss: 18.8100
# Epoch 188/400
#  - 0s - loss: 22.0275 - val_loss: 18.8848
# Epoch 189/400
#  - 0s - loss: 21.6200 - val_loss: 18.8530
# Epoch 190/400
#  - 0s - loss: 21.8760 - val_loss: 18.8223
# Epoch 191/400
#  - 0s - loss: 21.7607 - val_loss: 18.9350
# Epoch 192/400
#  - 0s - loss: 21.9424 - val_loss: 19.0496
# Epoch 193/400
#  - 0s - loss: 22.2055 - val_loss: 18.9760
# Epoch 194/400
#  - 0s - loss: 21.6116 - val_loss: 19.3175
# Epoch 195/400
#  - 0s - loss: 21.7379 - val_loss: 19.4599
# Epoch 196/400
#  - 0s - loss: 21.8158 - val_loss: 19.2807
# Epoch 197/400
#  - 0s - loss: 21.9990 - val_loss: 19.0938
# Epoch 198/400
#  - 0s - loss: 21.9233 - val_loss: 19.2168
# Epoch 199/400
#  - 0s - loss: 21.8659 - val_loss: 19.1739
# Epoch 200/400
#  - 0s - loss: 21.8364 - val_loss: 19.3497
# Epoch 201/400
#  - 0s - loss: 21.9038 - val_loss: 19.3354
# Epoch 202/400
#  - 0s - loss: 22.1251 - val_loss: 19.4512
# Epoch 203/400
#  - 0s - loss: 21.9687 - val_loss: 19.0456
# Epoch 204/400
#  - 0s - loss: 21.6609 - val_loss: 18.7050
# Epoch 205/400
#  - 0s - loss: 21.9187 - val_loss: 18.6029
# Epoch 206/400
#  - 0s - loss: 21.7512 - val_loss: 18.8171
# Epoch 207/400
#  - 0s - loss: 21.6745 - val_loss: 18.9410
# Epoch 208/400
#  - 0s - loss: 21.9337 - val_loss: 18.9615
# Epoch 209/400
#  - 0s - loss: 21.6896 - val_loss: 18.9703
# Epoch 210/400
#  - 0s - loss: 21.6756 - val_loss: 19.0143
# Epoch 211/400
#  - 0s - loss: 21.8684 - val_loss: 18.8495
# Epoch 212/400
#  - 0s - loss: 21.5059 - val_loss: 18.8746
# Epoch 213/400
#  - 0s - loss: 22.0882 - val_loss: 18.8746
# Epoch 214/400
#  - 0s - loss: 21.5546 - val_loss: 19.0745
# Epoch 215/400
#  - 0s - loss: 21.4843 - val_loss: 19.1051
# Epoch 216/400
#  - 0s - loss: 21.7705 - val_loss: 19.0884
# Epoch 217/400
#  - 0s - loss: 21.9401 - val_loss: 19.1344
# Epoch 218/400
#  - 0s - loss: 21.8934 - val_loss: 19.2355
# Epoch 219/400
#  - 0s - loss: 21.6763 - val_loss: 19.3069
# Epoch 220/400
#  - 0s - loss: 21.7569 - val_loss: 19.3456
# Epoch 221/400
#  - 0s - loss: 21.5768 - val_loss: 19.4540
# Epoch 222/400
#  - 0s - loss: 21.5077 - val_loss: 19.3708
# Epoch 223/400
#  - 0s - loss: 21.5745 - val_loss: 19.3176
# Epoch 224/400
#  - 0s - loss: 21.6115 - val_loss: 19.2133
# Epoch 225/400
#  - 0s - loss: 21.9614 - val_loss: 19.2522
# Epoch 226/400
#  - 0s - loss: 21.7329 - val_loss: 19.4184
# Epoch 227/400
#  - 0s - loss: 22.0278 - val_loss: 19.3823
# Epoch 228/400
#  - 0s - loss: 21.4818 - val_loss: 19.2042
# Epoch 229/400
#  - 0s - loss: 21.7099 - val_loss: 19.1033
# Epoch 230/400
#  - 0s - loss: 21.0683 - val_loss: 19.0922
# Epoch 231/400
#  - 0s - loss: 21.4803 - val_loss: 19.0198
# Epoch 232/400
#  - 0s - loss: 20.9421 - val_loss: 18.9597
# Epoch 233/400
#  - 0s - loss: 21.5709 - val_loss: 19.0400
# Epoch 234/400
#  - 0s - loss: 21.5844 - val_loss: 19.2540
# Epoch 235/400
#  - 0s - loss: 21.6487 - val_loss: 19.2925
# Epoch 236/400
#  - 0s - loss: 21.8983 - val_loss: 19.3737
# Epoch 237/400
#  - 0s - loss: 21.8333 - val_loss: 19.4277
# Epoch 238/400
#  - 0s - loss: 21.4805 - val_loss: 19.3687
# Epoch 239/400
#  - 0s - loss: 21.7108 - val_loss: 19.1343
# Epoch 240/400
#  - 0s - loss: 21.9408 - val_loss: 19.1648
# Epoch 241/400
#  - 0s - loss: 21.4113 - val_loss: 19.3221
# Epoch 242/400
#  - 0s - loss: 21.6503 - val_loss: 19.6077
# Epoch 243/400
#  - 0s - loss: 21.6897 - val_loss: 19.5330
# Epoch 244/400
#  - 0s - loss: 21.3510 - val_loss: 19.5462
# Epoch 245/400
#  - 0s - loss: 21.3516 - val_loss: 19.4139
# Epoch 246/400
#  - 0s - loss: 21.4451 - val_loss: 19.2895
# Epoch 247/400
#  - 0s - loss: 21.3554 - val_loss: 19.2658
# Epoch 248/400
#  - 0s - loss: 21.8826 - val_loss: 19.1827
# Epoch 249/400
#  - 0s - loss: 21.3721 - val_loss: 19.1878
# Epoch 250/400
#  - 0s - loss: 21.4405 - val_loss: 19.1537
# Epoch 251/400
#  - 0s - loss: 20.7982 - val_loss: 19.3102
# Epoch 252/400
#  - 0s - loss: 21.3888 - val_loss: 19.3674
# Epoch 253/400
#  - 0s - loss: 21.3107 - val_loss: 19.4411
# Epoch 254/400
#  - 0s - loss: 21.5865 - val_loss: 19.1979
# Epoch 255/400
#  - 0s - loss: 21.2325 - val_loss: 18.9838
# Epoch 256/400
#  - 0s - loss: 21.7663 - val_loss: 19.1487
# Epoch 257/400
#  - 0s - loss: 21.7600 - val_loss: 19.4973
# Epoch 258/400
#  - 0s - loss: 21.4105 - val_loss: 19.3185
# Epoch 259/400
#  - 0s - loss: 21.5220 - val_loss: 19.2124
# Epoch 260/400
#  - 0s - loss: 21.2369 - val_loss: 19.1537
# Epoch 261/400
#  - 0s - loss: 21.3133 - val_loss: 19.3721
# Epoch 262/400
#  - 0s - loss: 21.3606 - val_loss: 19.4652
# Epoch 263/400
#  - 0s - loss: 21.7152 - val_loss: 19.1890
# Epoch 264/400
#  - 0s - loss: 21.2839 - val_loss: 18.9427
# Epoch 265/400
#  - 0s - loss: 21.0406 - val_loss: 18.9889
# Epoch 266/400
#  - 0s - loss: 21.6209 - val_loss: 19.2753
# Epoch 267/400
#  - 0s - loss: 21.2190 - val_loss: 19.5013
# Epoch 268/400
#  - 0s - loss: 20.9712 - val_loss: 19.6339
# Epoch 269/400
#  - 0s - loss: 21.4071 - val_loss: 19.5056
# Epoch 270/400
#  - 0s - loss: 20.6801 - val_loss: 19.3938
# Epoch 271/400
#  - 0s - loss: 20.9331 - val_loss: 19.4251
# Epoch 272/400
#  - 0s - loss: 21.5658 - val_loss: 19.4540
# Epoch 273/400
#  - 0s - loss: 21.1081 - val_loss: 19.2672
# Epoch 274/400
#  - 0s - loss: 21.1001 - val_loss: 19.1515
# Epoch 275/400
#  - 0s - loss: 21.6401 - val_loss: 19.1284
# Epoch 276/400
#  - 0s - loss: 21.3016 - val_loss: 19.4031
# Epoch 277/400
#  - 0s - loss: 21.2309 - val_loss: 19.5603
# Epoch 278/400
#  - 0s - loss: 21.3226 - val_loss: 19.6832
# Epoch 279/400
#  - 0s - loss: 21.1627 - val_loss: 19.4868
# Epoch 280/400
#  - 0s - loss: 21.0597 - val_loss: 19.2502
# Epoch 281/400
#  - 0s - loss: 21.0815 - val_loss: 19.5055
# Epoch 282/400
#  - 0s - loss: 21.1198 - val_loss: 19.6441
# Epoch 283/400
#  - 0s - loss: 21.1923 - val_loss: 19.5171
# Epoch 284/400
#  - 0s - loss: 21.3453 - val_loss: 19.2129
# Epoch 285/400
#  - 0s - loss: 21.2736 - val_loss: 19.1930
# Epoch 286/400
#  - 0s - loss: 21.3776 - val_loss: 19.5301
# Epoch 287/400
#  - 0s - loss: 21.6337 - val_loss: 19.5181
# Epoch 288/400
#  - 0s - loss: 20.9299 - val_loss: 19.4239
# Epoch 289/400
#  - 0s - loss: 21.2839 - val_loss: 19.3561
# Epoch 290/400
#  - 0s - loss: 21.5198 - val_loss: 19.3348
# Epoch 291/400
#  - 0s - loss: 20.8542 - val_loss: 19.3457
# Epoch 292/400
#  - 0s - loss: 20.8476 - val_loss: 19.4116
# Epoch 293/400
#  - 0s - loss: 20.9760 - val_loss: 19.4156
# Epoch 294/400
#  - 0s - loss: 21.2579 - val_loss: 19.3740
# Epoch 295/400
#  - 0s - loss: 21.3260 - val_loss: 19.0243
# Epoch 296/400
#  - 0s - loss: 21.5141 - val_loss: 19.2402
# Epoch 297/400
#  - 0s - loss: 20.8819 - val_loss: 19.4412
# Epoch 298/400
#  - 0s - loss: 20.6372 - val_loss: 19.5188
# Epoch 299/400
#  - 0s - loss: 20.9581 - val_loss: 19.5773
# Epoch 300/400
#  - 0s - loss: 21.3217 - val_loss: 19.3743
# Epoch 301/400
#  - 0s - loss: 20.6652 - val_loss: 19.2811
# Epoch 302/400
#  - 0s - loss: 21.3951 - val_loss: 19.3391
# Epoch 303/400
#  - 0s - loss: 21.0164 - val_loss: 19.3490
# Epoch 304/400
#  - 0s - loss: 20.9941 - val_loss: 19.2119
# Epoch 305/400
#  - 0s - loss: 21.6719 - val_loss: 19.1099
# Epoch 306/400
#  - 0s - loss: 21.2691 - val_loss: 19.0771
# Epoch 307/400
#  - 0s - loss: 21.4430 - val_loss: 19.6194
# Epoch 308/400
#  - 0s - loss: 20.7670 - val_loss: 19.9293
# Epoch 309/400
#  - 0s - loss: 21.4481 - val_loss: 19.8221
# Epoch 310/400
#  - 0s - loss: 20.9595 - val_loss: 19.5646
# Epoch 311/400
#  - 0s - loss: 21.3996 - val_loss: 19.4695
# Epoch 312/400
#  - 0s - loss: 20.8706 - val_loss: 19.4496
# Epoch 313/400
#  - 0s - loss: 20.9681 - val_loss: 19.5204
# Epoch 314/400
#  - 0s - loss: 21.0759 - val_loss: 19.5369
# Epoch 315/400
#  - 0s - loss: 20.9956 - val_loss: 19.6633
# Epoch 316/400
#  - 0s - loss: 21.1466 - val_loss: 19.7729
# Epoch 317/400
#  - 0s - loss: 21.2745 - val_loss: 19.3770
# Epoch 318/400
#  - 0s - loss: 21.1770 - val_loss: 19.1015
# Epoch 319/400
#  - 0s - loss: 21.3084 - val_loss: 19.0787
# Epoch 320/400
#  - 0s - loss: 20.9469 - val_loss: 19.1383
# Epoch 321/400
#  - 0s - loss: 20.8609 - val_loss: 19.4178
# Epoch 322/400
#  - 0s - loss: 20.6455 - val_loss: 19.5521
# Epoch 323/400
#  - 0s - loss: 21.0284 - val_loss: 19.6078
# Epoch 324/400
#  - 0s - loss: 21.0515 - val_loss: 19.5373
# Epoch 325/400
#  - 0s - loss: 21.4383 - val_loss: 19.4935
# Epoch 326/400
#  - 0s - loss: 20.7364 - val_loss: 19.3862
# Epoch 327/400
#  - 0s - loss: 21.0348 - val_loss: 19.4346
# Epoch 328/400
#  - 0s - loss: 20.7172 - val_loss: 19.5391
# Epoch 329/400
#  - 0s - loss: 20.6830 - val_loss: 19.4676
# Epoch 330/400
#  - 0s - loss: 20.7795 - val_loss: 19.6241
# Epoch 331/400
#  - 0s - loss: 20.9214 - val_loss: 19.8109
# Epoch 332/400
#  - 0s - loss: 21.0901 - val_loss: 19.6658
# Epoch 333/400
#  - 0s - loss: 21.1526 - val_loss: 19.5539
# Epoch 334/400
#  - 0s - loss: 20.7655 - val_loss: 19.6593
# Epoch 335/400
#  - 0s - loss: 21.2614 - val_loss: 19.6071
# Epoch 336/400
#  - 0s - loss: 20.9755 - val_loss: 19.6044
# Epoch 337/400
#  - 0s - loss: 20.9208 - val_loss: 19.5544
# Epoch 338/400
#  - 0s - loss: 21.1907 - val_loss: 19.2794
# Epoch 339/400
#  - 0s - loss: 20.6323 - val_loss: 19.1927
# Epoch 340/400
#  - 0s - loss: 20.8784 - val_loss: 19.2828
# Epoch 341/400
#  - 0s - loss: 20.7821 - val_loss: 19.4192
# Epoch 342/400
#  - 0s - loss: 20.7408 - val_loss: 19.6323
# Epoch 343/400
#  - 0s - loss: 20.9168 - val_loss: 19.4533
# Epoch 344/400
#  - 0s - loss: 20.7291 - val_loss: 19.4100
# Epoch 345/400
#  - 0s - loss: 21.0270 - val_loss: 19.3636
# Epoch 346/400
#  - 0s - loss: 20.2424 - val_loss: 19.4947
# Epoch 347/400
#  - 0s - loss: 20.8101 - val_loss: 19.6559
# Epoch 348/400
#  - 0s - loss: 20.6127 - val_loss: 19.6464
# Epoch 349/400
#  - 0s - loss: 20.8641 - val_loss: 19.7091
# Epoch 350/400
#  - 0s - loss: 21.0355 - val_loss: 19.7532
# Epoch 351/400
#  - 0s - loss: 20.8757 - val_loss: 19.6761
# Epoch 352/400
#  - 0s - loss: 20.9515 - val_loss: 19.9614
# Epoch 353/400
#  - 0s - loss: 20.4822 - val_loss: 19.9845
# Epoch 354/400
#  - 0s - loss: 20.8736 - val_loss: 19.9813
# Epoch 355/400
#  - 0s - loss: 20.9190 - val_loss: 20.1372
# Epoch 356/400
#  - 0s - loss: 21.1203 - val_loss: 19.9016
# Epoch 357/400
#  - 0s - loss: 20.5243 - val_loss: 19.6343
# Epoch 358/400
#  - 0s - loss: 20.4370 - val_loss: 19.4512
# Epoch 359/400
#  - 0s - loss: 20.4306 - val_loss: 19.4662
# Epoch 360/400
#  - 0s - loss: 20.5291 - val_loss: 19.5827
# Epoch 361/400
#  - 0s - loss: 20.8953 - val_loss: 19.4881
# Epoch 362/400
#  - 0s - loss: 20.3311 - val_loss: 19.5744
# Epoch 363/400
#  - 0s - loss: 20.9503 - val_loss: 19.5025
# Epoch 364/400
#  - 0s - loss: 20.4996 - val_loss: 19.5653
# Epoch 365/400
#  - 0s - loss: 20.7624 - val_loss: 19.6003
# Epoch 366/400
#  - 0s - loss: 20.5371 - val_loss: 19.7014
# Epoch 367/400
#  - 0s - loss: 20.4045 - val_loss: 19.7785
# Epoch 368/400
#  - 0s - loss: 20.1126 - val_loss: 19.4949
# Epoch 369/400
#  - 0s - loss: 20.5180 - val_loss: 19.7621
# Epoch 370/400
#  - 0s - loss: 21.1978 - val_loss: 19.9770
# Epoch 371/400
#  - 0s - loss: 21.2136 - val_loss: 19.9555
# Epoch 372/400
#  - 0s - loss: 20.7637 - val_loss: 19.5852
# Epoch 373/400
#  - 0s - loss: 20.8866 - val_loss: 19.3932
# Epoch 374/400
#  - 0s - loss: 20.6155 - val_loss: 19.5569
# Epoch 375/400
#  - 0s - loss: 20.4105 - val_loss: 19.8718
# Epoch 376/400
#  - 0s - loss: 20.6785 - val_loss: 20.0520
# Epoch 377/400
#  - 0s - loss: 20.7020 - val_loss: 19.9146
# Epoch 378/400
#  - 0s - loss: 20.5633 - val_loss: 19.9399
# Epoch 379/400
#  - 0s - loss: 20.4842 - val_loss: 19.8794
# Epoch 380/400
#  - 0s - loss: 20.6234 - val_loss: 19.7417
# Epoch 381/400
#  - 0s - loss: 20.6354 - val_loss: 19.7480
# Epoch 382/400
#  - 0s - loss: 20.5409 - val_loss: 19.6046
# Epoch 383/400
#  - 0s - loss: 20.9276 - val_loss: 19.5589
# Epoch 384/400
#  - 0s - loss: 20.2976 - val_loss: 19.5528
# Epoch 385/400
#  - 0s - loss: 20.1011 - val_loss: 19.8974
# Epoch 386/400
#  - 0s - loss: 20.2672 - val_loss: 19.9182
# Epoch 387/400
#  - 0s - loss: 20.7200 - val_loss: 19.6146
# Epoch 388/400
#  - 0s - loss: 20.3198 - val_loss: 19.3965
# Epoch 389/400
#  - 0s - loss: 20.0825 - val_loss: 19.6027
# Epoch 390/400
#  - 0s - loss: 20.4788 - val_loss: 19.6253
# Epoch 391/400
#  - 0s - loss: 20.8114 - val_loss: 19.7702
# Epoch 392/400
#  - 0s - loss: 20.8826 - val_loss: 19.7749
# Epoch 393/400
#  - 0s - loss: 20.6409 - val_loss: 19.6948
# Epoch 394/400
#  - 0s - loss: 20.2306 - val_loss: 19.7182
# Epoch 395/400
#  - 0s - loss: 19.8729 - val_loss: 19.6138
# Epoch 396/400
#  - 0s - loss: 19.8822 - val_loss: 19.4487
# Epoch 397/400
#  - 0s - loss: 19.9354 - val_loss: 19.5207
# Epoch 398/400
#  - 0s - loss: 20.3825 - val_loss: 19.7518
# Epoch 399/400
#  - 0s - loss: 19.9653 - val_loss: 19.6603
# Epoch 400/400
#  - 0s - loss: 20.6953 - val_loss: 19.7797

# %%
output_sj = pd.DataFrame(np.append(sj_train_preds, sj_test_preds))

# %%
fig, ax = plt.subplots(figsize = (15,10))
output_sj[0].plot(ax = ax)
ax.axvline(len(sj_train_preds), linestyle = 'dashed', color = 'black')
ax.set_ylabel('total_cases')
# Out:
# Text(0, 0.5, 'total_cases')

# %%
iq_feature_train_log_cases = iq_feature_train.copy()
iq_feature_train_log_cases['total_cases'] = np.log(1 + iq_feature_train_log_cases['total_cases'])

# %%
iq_model, iq_train_preds, iq_test_preds = fit_and_predict_LSTM(iq_feature_train.iloc[70:,:], iq_feature_test, epochs = 50, n_hidden = 40, verbose = 2)
# Out:
# Train on 240 samples, validate on 200 samples
# Epoch 1/50
#  - 1s - loss: 8.7526 - val_loss: 8.8502
# Epoch 2/50
#  - 0s - loss: 8.6515 - val_loss: 8.7786
# Epoch 3/50
#  - 0s - loss: 8.5855 - val_loss: 8.7014
# Epoch 4/50
#  - 0s - loss: 8.4753 - val_loss: 8.6147
# Epoch 5/50
#  - 0s - loss: 8.3650 - val_loss: 8.5157
# Epoch 6/50
#  - 0s - loss: 8.2213 - val_loss: 8.4055
# Epoch 7/50
#  - 0s - loss: 8.1231 - val_loss: 8.2860
# Epoch 8/50
#  - 0s - loss: 7.9691 - val_loss: 8.1505
# Epoch 9/50
#  - 0s - loss: 7.8039 - val_loss: 7.9968
# Epoch 10/50
#  - 0s - loss: 7.6859 - val_loss: 7.8291
# Epoch 11/50
#  - 0s - loss: 7.4847 - val_loss: 7.6504
# Epoch 12/50
#  - 0s - loss: 7.2980 - val_loss: 7.4545
# Epoch 13/50
#  - 0s - loss: 7.0673 - val_loss: 7.2448
# Epoch 14/50
#  - 0s - loss: 7.0051 - val_loss: 7.0435
# Epoch 15/50
#  - 0s - loss: 6.8842 - val_loss: 6.8648
# Epoch 16/50
#  - 0s - loss: 6.8053 - val_loss: 6.7097
# Epoch 17/50
#  - 0s - loss: 6.7960 - val_loss: 6.5816
# Epoch 18/50
#  - 0s - loss: 6.6282 - val_loss: 6.4714
# Epoch 19/50
#  - 0s - loss: 6.6664 - val_loss: 6.3801
# Epoch 20/50
#  - 0s - loss: 6.5055 - val_loss: 6.3212
# Epoch 21/50
#  - 0s - loss: 6.5740 - val_loss: 6.2764
# Epoch 22/50
#  - 0s - loss: 6.5298 - val_loss: 6.2413
# Epoch 23/50
#  - 0s - loss: 6.5256 - val_loss: 6.2123
# Epoch 24/50
#  - 0s - loss: 6.5932 - val_loss: 6.1841
# Epoch 25/50
#  - 0s - loss: 6.4305 - val_loss: 6.1603
# Epoch 26/50
#  - 0s - loss: 6.5328 - val_loss: 6.1467
# Epoch 27/50
#  - 0s - loss: 6.2935 - val_loss: 6.1497
# Epoch 28/50
#  - 0s - loss: 6.4188 - val_loss: 6.1680
# Epoch 29/50
#  - 0s - loss: 6.5017 - val_loss: 6.1850
# Epoch 30/50
#  - 0s - loss: 6.3169 - val_loss: 6.1887
# Epoch 31/50
#  - 0s - loss: 6.4368 - val_loss: 6.1882
# Epoch 32/50
#  - 0s - loss: 6.2389 - val_loss: 6.1914
# Epoch 33/50
#  - 0s - loss: 6.1381 - val_loss: 6.1927
# Epoch 34/50
#  - 0s - loss: 6.2264 - val_loss: 6.1822
# Epoch 35/50
#  - 0s - loss: 6.1923 - val_loss: 6.1617
# Epoch 36/50
#  - 0s - loss: 6.1084 - val_loss: 6.1334
# Epoch 37/50
#  - 0s - loss: 6.0897 - val_loss: 6.1029
# Epoch 38/50
#  - 0s - loss: 5.9890 - val_loss: 6.0767
# Epoch 39/50
#  - 0s - loss: 5.9985 - val_loss: 6.0591
# Epoch 40/50
#  - 0s - loss: 6.1129 - val_loss: 6.0463
# Epoch 41/50
#  - 0s - loss: 6.1028 - val_loss: 6.0420
# Epoch 42/50
#  - 0s - loss: 6.1056 - val_loss: 6.0476
# Epoch 43/50
#  - 0s - loss: 5.9549 - val_loss: 6.0575
# Epoch 44/50
#  - 0s - loss: 6.0059 - val_loss: 6.0617
# Epoch 45/50
#  - 0s - loss: 5.8683 - val_loss: 6.0561
# Epoch 46/50
#  - 0s - loss: 5.8259 - val_loss: 6.0454
# Epoch 47/50
#  - 0s - loss: 5.8811 - val_loss: 6.0263
# Epoch 48/50
#  - 0s - loss: 5.8908 - val_loss: 6.0073
# Epoch 49/50
#  - 0s - loss: 5.8411 - val_loss: 5.9969
# Epoch 50/50
#  - 0s - loss: 5.8824 - val_loss: 5.9847

# %%
output_iq = pd.DataFrame(np.append(iq_train_preds, iq_test_preds))
output_iq['total_cases'] = np.expm1(output_iq[0]).astype(int)

# %%
fig, ax = plt.subplots(figsize = (15,10))
output_iq['total_cases'].plot(ax = ax)
ax.axvline(len(iq_train_preds), linestyle = 'dashed', color = 'black')
ax.set_ylabel('total_cases')
# Out:
# Text(0, 0.5, 'total_cases')

# %%
# Finalize model
sj_model = pd.DataFrame(sj_test_preds.astype(int), columns = ['total_cases'])
sj_model['year'] = sj_feature_test['year']
sj_model['weekofyear'] = sj_feature_test['weekofyear']
sj_model['city'] = 'sj'

# %%
iq_model = pd.DataFrame(iq_test_preds.astype(int), columns = ['total_cases'])
iq_model['year'] = iq_feature_test['year']
iq_model['weekofyear'] = iq_feature_test['weekofyear']
iq_model['city'] = 'iq'

# %%
model = sj_model.append(iq_model)[['city', 'year', 'weekofyear', 'total_cases']]
model.loc[model['total_cases'] < 0, 'total_cases'] = 0

# %%
model
# Out:
#     city  year  weekofyear  total_cases
# 0     sj  2008          18            4
# 1     sj  2008          19            5
# 2     sj  2008          20            5
# 3     sj  2008          21           10
# 4     sj  2008          22           10
# ..   ...   ...         ...          ...
# 151   iq  2013          22            3
# 152   iq  2013          23            2
# 153   iq  2013          24            1
# 154   iq  2013          25            1
# 155   iq  2013          26            2
#
# [416 rows x 4 columns]

# %%
model[model['city'] == 'sj']['total_cases'].plot()
# Out:
# <AxesSubplot:>

# %%
model[model['city'] == 'iq']['total_cases'].plot()
# Out:
# <AxesSubplot:>

# %%
import time
today = time.strftime('%d-%m-%Y')
model.to_csv(model_path + '/Keras_LSTM_' + output_feature_fname + '_' + today + '.csv', index = False)
